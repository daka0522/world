# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
WHITE = np.array([255, 255, 255])
GREEN = np.array([0, 255, 0])
BLACK = np.array([0, 0, 0])

# %%
steps = 100
gradient = np.linspace(WHITE, GREEN, steps)
gradient2 = np.linspace(GREEN, WHITE, steps)

# %%
full_gradient = np.concatenate((gradient, gradient2))

# %%
# Visualize the gradient
plt.figure(figsize=(11, 3))
for i, color in enumerate(full_gradient):
    plt.axvline(x=i, color=color / 255, linewidth=4)
plt.axis('off')
plt.show()

# %%
steps = 100
color1 = np.random.randint(0, 255, (4, 3))

# %%
step_min = 100
step_max = 300

colors = np.random.randint(0, 255, (3, 3))
step0 = np.random.randint(step_min, step_max)
step1 = np.random.randint(step_min, step_max)
step2 = np.random.randint(step_min, step_max)

# %%
end_line = 30

c0 = np.linspace(WHITE, colors[0], end_line, dtype=np.uint8)
c1 = np.linspace(colors[0], colors[1], step1, dtype=np.uint8)
c2 = np.linspace(colors[1], colors[2], step2, dtype=np.uint8)
c3 = np.linspace(colors[2], colors[1], step2, dtype=np.uint8)
c4 = np.linspace(colors[1], colors[0], step1, dtype=np.uint8)
c5 = np.linspace(colors[0], WHITE, end_line, dtype=np.uint8)

cc = np.concatenate((c0, c1, c2, c3, c4, c5))
# cc = np.concatenate((c1, c2, c3, c4))
cc.shape
# Out:
# (1102, 3)

# %%
# Visualize the gradient
plt.figure(figsize=(3, 5))
for i, color in enumerate(cc):
    # plt.axvline(x=i, color=color / 255, linewidth=4)
    plt.axhline(y=i, color=color / 255, linewidth=1)
plt.axis('off')
plt.show()

# %% [markdown]
# # Animation

# %%
# Display the animation in the notebook
from IPython.display import HTML
from matplotlib.animation import FuncAnimation
from matplotlib.patches import Rectangle

# %%
# Initialize a blank line
line = ax.axhline(y=1, color=WHITE / 255, linewidth=50)


# Animate the Color Transition with Rectangle
fig, ax = plt.subplots(figsize=(3, 3))
ax.axis('off')

# Initialize a rectangle
rect = Rectangle((0, 0), 1, 1, color=WHITE / 255)
ax.add_patch(rect)

def update(frame):
    """Update the rectangle color for each frame."""
    rect.set_color(cc[frame] / 255)
    return rect,

# Create the animation
ani = FuncAnimation(fig, update, frames=len(cc), interval=30, blit=True)

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
